# %%
pip install transformers

# %%
from transformers import pipeline

# Load the question answering pipeline
qa_pipeline = pipeline('question-answering', model='distilbert-base-cased-distilled-squad', tokenizer='distilbert-base-cased-distilled-squad')

# Provide context (the passage or document) and ask a question
context = """
The Transformers library by Hugging Face is a popular library for natural language processing (NLP) tasks. It provides pre-trained models for various NLP tasks, including question answering.
"""

question = "What is Transformers library used for?"

# Get the answer
answer = qa_pipeline(question=question, context=context)

# Print the answer
print(answer)
# Out:
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# {'score': 0.549256443977356, 'start': 67, 'end': 106, 'answer': 'natural language processing (NLP) tasks'}

# %%
from transformers import DistilBertForQuestionAnswering, DistilBertTokenizer
import torch

# Load pre-trained model and tokenizer
model_name = 'distilbert-base-cased-distilled-squad'
model = DistilBertForQuestionAnswering.from_pretrained(model_name)
tokenizer = DistilBertTokenizer.from_pretrained(model_name)

# Encode the context and question
encoding = tokenizer(context, question, return_tensors='pt')

# Get the answer
outputs = model(**encoding)
start_scores, end_scores = outputs.start_logits, outputs.end_logits

# Get the answer span
start_index = torch.argmax(start_scores)
end_index = torch.argmax(end_scores)
answer = tokenizer.convert_tokens_to_string(tokenizer.convert_ids_to_tokens(encoding['input_ids'][0][start_index:end_index + 1]))

# Print the answer
print(answer)
# Out:
# natural language processing ( NLP ) tasks
