# %% [markdown]
# Implementation of Data Structures in Python
#
# a. Initialize the list to store the input elements.
#
# b. Initialize found-False. c. Enter the item to be searched (match item).
#
# d. For each element in the list 1. if match item = value
#
# a. return match item's position.
#
# e. If the match item is not in the list, display an error message that the item is not found in
#
# the list.

# %%
input_list = [1, 266, 3877, 487, 5654, -60]


found = False

match_item = int(input("Enter the item to search: "))


for i, value in enumerate(input_list):
    
    if match_item == value:
        print(f"{match_item} found at position {i}")
        found = True
        break


if not found:
    print(f"{match_item} is not found in the list.")
# Out:
# Enter the item to search: 9
# 9 is not found in the list.

# %% [markdown]
# 2. Write a Python program to implement binary search to find the target values from the list:
#
# a. Create a separate function to do binary search
#
# b. Get the number of inputs from the user.
#
# c. Store the inputs individually in a list. d. In binary search function at first sort the list in order to start the search from middle of the
#
# list.
#
# e. Compare the middle element to right and left elements to search target element. f. If greater, move to right of list or else move to another side of the list.
#
# g. Print the result along with the position of the element.

# %%
def b_s(data,target):
    s=0

    e=len(data)-1
    
    while(s<=e ):
        mid= (s+e)//2
        if data[mid]==target:
            return mid
        elif data[mid]>target:
             e=mid-1
        else:
            s=mid+1
        
    return -1      



data=[]
n=int(input('Enter # of elements to be inserted:\t'))
for i in range(0,n):
    x=int(input('Enter the Element %d:'%(i+1)))
    data.append(x)

target =int(input("enter the target: ")) 


result = b_s(data, target)

if result != -1:
    print(f"Element {target} found at index {result}")
else:
    print(f"Element {target} not found in the list")
# Out:
# Enter # of elements to be inserted:	5
# Enter the Element 1:43
# Enter the Element 2:76
# Enter the Element 3:89
# Enter the Element 4:241
# Enter the Element 5:777
# enter the target: 43
# Element 43 found at index 0

# %% [markdown]
# 3. Write a Python program for sorting a list of elements using selection sort algorithm: a. Assume two lists: Sorted list- Initially empty and Unsorted List-Given input list. b. In the first iteration, find the smallest element in the unsorted list and place it in the sorted
#
# list.
#
# c. In the second iteration, find the smallest element in the unsorted list and place it in the
#
# correct position by comparing with the element in the sorted list. d. In the third iteration, again find the smallest element in the unsorted list and place it in the
#
# correct position by comparing with the elements in the sorted list.
#
# e. This process continues till the unsorted list becomes empty.
#
# f. Display the sorted list.

# %%
def selection_sort(arr):
    sorted_list = []  

    while arr: 
        min_index = 0  
        for i in range(1, len(arr)):
            if arr[i] < arr[min_index]:
                min_index = i  
        sorted_list.append(arr.pop(min_index)) 

    return sorted_list


input_list=[]
n=int(input('Enter # of elements to be inserted:\t'))
for i in range(0,n):
    x=int(input('Enter the Element %d:'%(i+1)))
    input_list.append(x)

sorted_result = selection_sort(input_list)

#  Display the sorted list.
print("Sorted List:", sorted_result)
# Out:
# Enter # of elements to be inserted:	7
# Enter the Element 1:7
# Enter the Element 2:0
# Enter the Element 3:-5
# Enter the Element 4:9
# Enter the Element 5:4
# Enter the Element 6:6
# Enter the Element 7:-8
# Sorted List: [-8, -5, 0, 4, 6, 7, 9]

# %% [markdown]
# 4. Write a Python program for sorting a list of elements using insertion sort algorithm: a. Assume two lists: Sorted list- Initially empty and Unsorted List-Given input list. b. In the first iteration, take the first element in the unsorted list and insert it in Sorted list.
#
# c. In the second iteration, take the second element in the given list and compare with the
#
# element in the sorted sub list and place it in the correct position.
#
# d. In the third iteration, take the third element in the given list and compare with the elements in the sorted sub list and place the elements in the correct position.
#
# e. This process continues until the last element is inserted in the sorted sub list.
#
# f. Display the sorted elements.

# %%
def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]  
        j = i - 1

        # Move elements of arr[0..i-1] that are greater than key
        # to one position ahead of their current position
        while j >= 0 and key < arr[j]:
            arr[j + 1] = arr[j]
            j -= 1

        arr[j + 1] = key  # Insert the key into its correct position

input_list=[]
n=int(input('Enter # of elements to be inserted:\t'))
for i in range(0,n):
    x=int(input('Enter the Element %d:'%(i+1)))
    input_list.append(x)
    

insertion_sort(input_list)


print("Sorted List:", input_list)

# %% [markdown]
# 6. Write a Python script to perform the following operations on a singly linked list
#
# a. Create a list b. Find the smallest element from the list
#
# c. Insert an element if it is not a duplicate element d. Display the elements in reverse order

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def append(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            return
        current = self.head
        while current.next:
            current = current.next
        current.next = new_node

    def find_smallest(self):
        if not self.head:
            return None
        smallest = self.head.data
        current = self.head.next
        while current:
            if current.data < smallest:
                smallest = current.data
            current = current.next
        return smallest

    def insert_if_not_duplicate(self, data):
        if not self.head:
            self.head = Node(data)
            return
        current = self.head
        while current.next:
            if current.data == data:
                return  
            current = current.next
        if current.data != data:
            current.next = Node(data)

    def display_reverse(self):
        stack = []
        current = self.head
        while current:
            stack.append(current.data)
            current = current.next
        while stack:
            print(stack.pop(), end=" -> ")
        print("None")

# Step a: Create a list
linked_list = LinkedList()
linked_list.append(10)
linked_list.append(20)
linked_list.append(35)
linked_list.append(10)  # Adding a duplicate element
linked_list.append(48)

# Step b: Find the smallest element
smallest = linked_list.find_smallest()
print(f"Smallest element: {smallest}")


linked_list.insert_if_not_duplicate(50)


print("Elements in reverse order:")
linked_list.display_reverse()
# Out:
# Smallest element: 10
# Elements in reverse order:
# 50 -> 48 -> 10 -> 35 -> 20 -> 10 -> None

# %% [markdown]
# 7. Write a python program to implement the various operations for Stack ADT
#
# i.) Push i.) Pop iii.) Display.

# %%
class Stack:
    def __init__(self):
        self.items = []

    def push(self, item):
        self.items.append(item)

    def pop(self):
        if not self.is_empty():
            return self.items.pop()
        else:
            print("Stack is empty. Cannot pop.")

    def display(self):
        if not self.is_empty():
            print("Stack Contents:")
            for item in reversed(self.items):
                print(item)
        else:
            print("Stack is empty.")

    def is_empty(self):
        return len(self.items) == 0


stack = Stack()

while True:
    print("\nStack Operations:")
    print("1. Push")
    print("2. Pop")
    print("3. Display")
    print("4. Quit")
    option = int(input("Enter choice (1/2/3/4): "))

    if option == 1:
        item = input("Enter the item to push: ")
        stack.push(item)
    elif option == 2:
        popped_item = stack.pop()
        if popped_item is not None:
            print(f"Popped item: {popped_item}")
    elif option == 3:
        stack.display()
    elif option == 4:
        print("Exiting program.")
        break
    else:
        print("Invalid choice. choose from 1 to 4.")
# Out:
# Stack Operations:
# 1. Push
# 2. Pop
# 3. Display
# 4. Quit
# Enter choice (1/2/3/4): 1
# Enter the item to push: 5
#
# Stack Operations:
# 1. Push
# 2. Pop
# 3. Display
# 4. Quit
# Enter choice (1/2/3/4): 1
# Enter the item to push: 5
#
# Stack Operations:
# 1. Push
# 2. Pop
# 3. Display
# 4. Quit
# Enter choice (1/2/3/4): 2
# Popped item: 5
#
# Stack Operations:
# 1. Push
# 2. Pop
# 3. Display
# 4. Quit
# Enter choice (1/2/3/4): 3
# Stack Contents:
# 5
#
# Stack Operations:
# 1. Push
# 2. Pop
# 3. Display
# 4. Quit
# Enter choice (1/2/3/4): 4
# Exiting program.

# %% [markdown]
# 8. Write a python script to implement the various operations for Queue ADT i.) Insert ii.) Delete iii.) Display.

# %%
class Queue:
    def __init__(self):
        self.items = []

    def insert(self, item):
        self.items.append(item)

    def delete(self):
        if not self.is_empty():
            return self.items.pop(0)
        else:
            return "Queue is empty. Cannot delete."

    def display(self):
        if not self.is_empty():
            print("Queue Contents:")
            for item in self.items:
                print(item)
        else:
            print("Queue is empty.")

    def is_empty(self):
        return len(self.items) == 0


queue = Queue()

while True:
    print("\nQueue Operations:")
    print("1. Insert (Enqueue)")
    print("2. Delete (Dequeue)")
    print("3. Display")
    print("4. Quit")
    opt = int(input("Enter  choice (1/2/3/4): "))

    if opt == 1:
        item = input("Enter an item to insert (enqueue): ")
        queue.insert(item)
        print(f"{item} inserted into the queue.")
    elif opt == 2:
        deleted_item = queue.delete()
        if deleted_item is not None:
            print(f"Deleted item: {deleted_item}")
        else:
            print("Queue is empty. Cannot delete.")
    elif opt == 3:
        queue.display()
    elif opt == 4:
        print("Exiting the program.")
        break
    else:
        print("Invalid choice. Please choose from 1 to 4.")
# Out:
# Queue Operations:
# 1. Insert (Enqueue)
# 2. Delete (Dequeue)
# 3. Display
# 4. Quit
# Enter  choice (1/2/3/4): 1
# Enter an item to insert (enqueue): 6
# 6 inserted into the queue.
#
# Queue Operations:
# 1. Insert (Enqueue)
# 2. Delete (Dequeue)
# 3. Display
# 4. Quit
# Enter  choice (1/2/3/4): 1
# Enter an item to insert (enqueue): 8
# 8 inserted into the queue.
#
# Queue Operations:
# 1. Insert (Enqueue)
# 2. Delete (Dequeue)
# 3. Display
# 4. Quit
# Enter  choice (1/2/3/4): 3
# Queue Contents:
# 6
# 8
#
# Queue Operations:
# 1. Insert (Enqueue)
# 2. Delete (Dequeue)
# 3. Display
# 4. Quit
# Enter  choice (1/2/3/4): 4
# Exiting the program.

# %%
9. Write a program in python to convert the following infix expression to its postfix form using push and

pop operations of a Stack a. A/B^C+D*E-F*G

b. (B^2-4*A*C)^(1/2)(100)

# %%
def infix_to_postfix(expression):
    precedence = {'+': 1, '-': 1, '*': 2, '/': 2, '^': 3}
    output = []
    stack = []

    for char in expression:
        if char.isalnum():
            output.append(char)
        elif char == '(':
            stack.append(char)
        elif char == ')':
            while stack and stack[-1] != '(':
                output.append(stack.pop())
            stack.pop()  # Pop the '('
        else:
            while stack and precedence.get(char, 0) <= precedence.get(stack[-1], 0):
                output.append(stack.pop())
            stack.append(char)

    while stack:
        output.append(stack.pop())

    return ''.join(output)

# Example expressions
expression_a = "A/B/C+D*E-F*G"
expression_b = "(B^2-4*A*C)(1/2)(100)"

# Convert and print the postfix expressions
postfix_a = infix_to_postfix(expression_a)
postfix_b = infix_to_postfix(expression_b)

print(f"Postfix for expression a: {postfix_a}")
print(f"Postfix for expression b: {postfix_b}")
# Out:
# Postfix for expression a: AB/C/DE*+FG*-
# Postfix for expression b: B2^4A*C*-12/100

# %% [markdown]
# 5 divide and conquer merge sort

# %%
def merge_sort(input_list):
    if len(input_list) > 1:
        mid = len(input_list) // 2  # Find the middle of the list
        left_half = input_list[:mid]  # Divide the list into left and right halves
        right_half = input_list[mid:]

        # Recursively sort the left and right halves
        merge_sort(left_half)
        merge_sort(right_half)

        # Initialize pointers for merging
        i = j = k = 0

        # Merge the two halves back into the original list
        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                input_list[k] = left_half[i]
                i += 1
            else:
                input_list[k] = right_half[j]
                j += 1
            k += 1

        # Check if any elements were left
        while i < len(left_half):
            input_list[k] = left_half[i]
            i += 1
            k += 1

        while j < len(right_half):
            input_list[k] = right_half[j]
            j += 1
            k += 1

# Get the input list from the user
input_list = [int(x) for x in input("Enter elements separated by spaces: ").split()]

# Call the merge_sort function to sort the list
merge_sort(input_list)

# Display the sorted list
print("Sorted List:", input_list)
